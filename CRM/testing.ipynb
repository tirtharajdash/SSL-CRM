# %%
datasets = ['786_0', 'A498', 'chess', 'trains']

# %%
#!python3 main2.py -f ./repeat-config-tr  -o ./res_pred_tr_0_delete_later -n 2
# Out:
# The system cannot find the path specified.

# %%
# !del demo
# !python3 main.py -f ./data/chess/config -o demo -n 1
# Out:
# Namespace(file='./data/chess/config', output='demo', saved_model=None, num_epochs=1, predict=False, explain=False, tune=False, verbose=False, gpu=False)
# ***Loading data***
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_features_pos file with 3361 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_features_neg file with 6639 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_1_features_pos file with 0 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_1_features_neg file with 18 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_2_features_pos file with 0 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_2_features_neg file with 14 instances (incl. empty instances).
# ***Creating CRM structure***
# ***Training CRM***
# ***Train Metrics***
# Accuracy: 0.6408490538597107
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# ...

# %%
# !del demo
# !python3 main.py -f ./data/chess/config -o demo -n 3
# Out:
# Namespace(file='./data/chess/config', output='demo', saved_model=None, num_epochs=3, predict=False, explain=False, tune=False, verbose=False, gpu=False)
# ***Loading data***
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_features_pos file with 3361 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_features_neg file with 6639 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_1_features_pos file with 0 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_1_features_neg file with 18 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_2_features_pos file with 0 instances (incl. empty instances).
# Loaded ./data/chess/raw/rand_crm_d3v6r1_test_2_features_neg file with 14 instances (incl. empty instances).
# ***Creating CRM structure***
# ***Training CRM***
# ***Train Metrics***
# tensor(0.6411)
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# ...

# %%
# !del demo
# !python3 main.py -f data/minichess/config -o demo -n 1 -v
# Out:
# Namespace(file='data/minichess/config', output='demo', saved_model=None, num_epochs=1, predict=False, explain=False, tune=False, verbose=True, gpu=False)
# ***Loading data***
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_features_pos file with 5 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_features_neg file with 5 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_1_features_pos file with 0 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_1_features_neg file with 5 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_2_features_pos file with 0 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_2_features_neg file with 5 instances (incl. empty instances).
# ***Creating CRM structure***
# ***Training CRM***
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#
# ...

# %%
# !del demo
# !python3 main.py -f data/minichess/config -o demo -n 1 -v
# Out:
# Namespace(file='data/minichess/config', output='demo', saved_model=None, num_epochs=1, predict=False, explain=False, tune=False, verbose=True, gpu=False)
# ***Loading data***
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_features_pos file with 5 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_features_neg file with 5 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_1_features_pos file with 0 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_1_features_neg file with 5 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_2_features_pos file with 0 instances (incl. empty instances).
# Loaded ./data/minichess/raw/rand_crm_d3v6r1_test_2_features_neg file with 5 instances (incl. empty instances).
# ***Creating CRM structure***
# ***Training CRM***
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#
# ...

# %%
# !python3 main2.py -f ./repeat-config  -o ./res_pred_datasets_tests_new_implem -n 10
